# %% [markdown]
# ### latex的连接
# https://en.wikibooks.org/wiki/LaTeX/Mathematics
# https://blog.csdn.net/NSJim/article/details/109045914

# %% [markdown]
# ![结构](../images/img.png)
# ![结构](../images/img_1.png)
# ![结构](../images/img_2.png)
# ![结构](../images/img_3.png)
# ![结构](../images/img_4.png)
# ![结构](../images/img_5.png)
# ![结构](../images/img_6.png)
# ![结构](../images/img_7.png)
# ![结构](../images/img_8.png)
# ![结构](../images/img_9.png)
# ![结构](../images/img_10.png)
# ![结构](../images/img_11.png)
# ![结构](../images/img_12.png)
# ![结构](../images/img_13.png)
# ![结构](../images/img_14.png)
# ![结构](../images/img_15.png)
#
# $\alpha$
# $\pi$
# $\omega$
# $\overline{abc}$
# $\sqrt{abc}$
# $\frac{abc}{xyz}$
# $\sum$
# $\int$
# $\iint$

# %% [markdown]
# $
# \begin{pmatrix}
#     1 & 2 \\
#     3 & 4
# \end{pmatrix}
# $

# %% [markdown]
# $E = mc^2$
#
# $\int_a^b f(x) \, dx$
#
# $
# \begin{cases}
# x + y = 5 \\
# 2x - y = 1
# \end{cases}
# $

# %%
## 在matplotlib中怎么使用
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

plt.title(r"y=sin(x)")
x = np.linspace(-np.pi, np.pi, 100)
plt.plot(x, np.sin(x))
plt.xlabel(r"$x$")
plt.ylabel(r"$\sin(x)$")
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r"-$\pi$", r"$\frac{\pi}{2}$", "0", r"$\frac{\pi}{2}$",r"$\pi$"]
           )


plt.show()

# %% [markdown]
# $x^n+y^n=z^n$
# $\begin{matrix}
# a & b & c \\
# d & e & f \\
# g & h & i
# \end{matrix}$
#
#
# \begin{matrix}
# a & b & c \\
# d & e & f \\
# g & h & i
# \end{matrix}
#
# $
# \int\frac{1}{x} dx = \ln |x| + C
# $
